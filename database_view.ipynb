# %%
import sqlite3 as lite
import pandas as pd
import os

# %% [markdown]
# # path to db

# %%
db_path = os.path.join(os.getcwd(), 'crawler_app', 'crawler_app', 'db', 'crawler.sqlite')

# %% [markdown]
# # code to get all table names

# %%
def get_table_names(database):
    ''' print out all the table names in an SQLite db'''
    conn = lite.connect(database)
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    print(cursor.fetchall())
    conn.close()
get_table_names(db_path)
# Out:
# [('Account',), ('History',), ('Graph_Data',)]

# %%
def execute_statement(query, database):
    """ Execute a query and return results as dataframe. 
        ARGS: SQL statement, database path
        RETURN: dataframe with results
    """
    conn = lite.connect(database)
    result = pd.read_sql_query(query, conn)
    conn.close()
    return result

# %%
query = \
"""
SELECT * FROM Account
"""
execute_statement(query, db_path)
# Out:
#                                  id username  \
# 0  1b94445e732d41b988a3cc85b770ae7c      cas
#
#                                        password_hash  \
# 0  $6$rounds=150000$Ice5btJm7KXiBEkb$C1KygbXDuT4h...
#
#                       created
# 0  2018-03-05 14:33:24.256492

# %%
query = \
"""
SELECT * FROM History
"""
execute_statement(query, db_path)
# Out:
#    auto_id                           user_id                      url  \
# 0        1  1b94445e732d41b988a3cc85b770ae7c  https://www.caelum.site
# 1        2  1b94445e732d41b988a3cc85b770ae7c  https://www.caelum.site
#
#   search_type  search_limit keyword                     created
# 0         BFS             2          2018-03-05 14:34:00.772343
# 1         BFS             2    Repo  2018-03-05 14:37:50.461050

# %%
query = \
"""
SELECT * FROM Graph_Data
"""
execute_statement(query, db_path)
# Out:
#                   domain  found  node_depth  node_id  parent_node  \
# 0        www.caelum.site  False           0        0            0
# 1   www.cas-donoghue.org  False           1        1            0
# 2             github.com  False           1        2            0
# 3       www.linkedin.com  False           2        3            1
# 4             github.com  False           2        4            1
# 5             github.com  False           2        5            1
# 6            twitter.com  False           2        6            1
# 7      stackoverflow.com  False           2        7            1
# 8      status.github.com  False           2        8            2
# 9             github.com  False           2        9            2
# 10            github.com  False           2       10            2
# 11            github.com  False           2       11            2
# 12       help.github.com  False           2       12            2
# 13       www.caelum.site  False           2       13            2
# 14       help.github.com  False           2       14            2
# 15            github.com  False           2       15            2
# 16       help.github.com  False           2       16            2
# 17       www.caelum.site  False           0        0            0
# 18  www.cas-donoghue.org  False           1        1            0
# 19            github.com   True           1        2            0
#
#                                                   url  lookup_id
# 0                             https://www.caelum.site          1
# 1                       https://www.cas-donoghue.org/          1
# 2      https://github.com/donoghuc/visual_web_crawler          1
# 3               https://www.linkedin.com/in/casadilla          1
# 4                         https://github.com/donoghuc          1
# 5           https://github.com/donoghuc/casadilla_web          1
# 6                        https://twitter.com/mkennedy          1
# 7   https://stackoverflow.com/users/9034974/cas-do...          1
# 8                          https://status.github.com/          1
# 9                     https://github.com/site/privacy          1
# 10                                https://github.com/          1
# 11                         https://github.com/contact          1
# 12  https://help.github.com/articles/which-remote-...          1
# 13                           https://www.caelum.site/          1
# 14  https://help.github.com/articles/github-terms-...          1
# 15                           https://github.com/about          1
# 16  https://help.github.com/articles/github-security/          1
# 17                            https://www.caelum.site          2
# 18                      https://www.cas-donoghue.org/          2
# 19     https://github.com/donoghuc/visual_web_crawler          2
