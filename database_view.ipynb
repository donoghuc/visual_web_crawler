# %%
import sqlite3 as lite
import pandas as pd
import os

# %% [markdown]
# # path to db

# %%
db_path = os.path.join(os.getcwd(), 'crawler_app', 'crawler_app', 'db', 'crawler.sqlite')

# %% [markdown]
# # code to get all table names

# %%
def get_table_names(database):
    ''' print out all the table names in an SQLite db'''
    conn = lite.connect(database)
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    print(cursor.fetchall())
    conn.close()
get_table_names(db_path)
# Out:
# [('Account',), ('History',), ('Graph_Data',)]

# %%
def execute_statement(query, database):
    """ Execute a query and return results as dataframe. 
        ARGS: SQL statement, database path
        RETURN: dataframe with results
    """
    conn = lite.connect(database)
    result = pd.read_sql_query(query, conn)
    conn.close()
    return result

# %%
query = \
"""
SELECT * FROM Account
"""
execute_statement(query, db_path)
# Out:
#                                  id username  \
# 0  a421f03ac5e6462fbd054ce4b915b6a6      cas
#
#                                        password_hash  \
# 0  $6$rounds=150000$xxzKm4Ka6yz4RDBf$BFrgt65zZ0jW...
#
#                       created
# 0  2018-03-01 09:05:37.089936

# %%
query = \
"""
SELECT * FROM History
"""
execute_statement(query, db_path)
# Out:
#    auto_id                           user_id                           url  \
# 0        1  a421f03ac5e6462fbd054ce4b915b6a6  https://www.cas-donoghue.org
#
#   search_type                     created
# 0         BFS  2018-03-01 09:14:23.240631

# %%
query = \
"""
SELECT * FROM Graph_Data
"""
execute_statement(query, db_path)
# Out:
#                             domain  node_depth  node_id  parent_node  \
# 0             www.cas-donoghue.org           0        0            0
# 1               donoghuc.github.io           1        1            0
# 2                    talkpython.fm           1        2            0
# 3                       github.com           1        3            0
# 4                       github.com           1        4            0
# 5                      twitter.com           1        5            0
# 6                stackoverflow.com           1        6            0
# 7                 www.linkedin.com           1        7            0
# 8              www.podcastinit.com           2        8            1
# 9                   pythonbytes.fm           2        9            1
# 10                 gimletmedia.com           2       10            1
# 11                   talkpython.fm           2       11            1
# 12  www.dataengineeringpodcast.com           2       12            1
# 13                   changelog.com           2       13            1
# 14                 testandcode.com           2       14            1
# 15                www.linkedin.com           2       15            1
# 16                 dataskeptic.com           2       16            1
# 17                     rollbar.com           2       17            2
# 18                  soundcloud.com           2       18            2
# 19                         cash.me           2       19            2
# 20                       gitter.im           2       20            2
# 21                    facebook.com           2       21            2
# 22                     twitter.com           2       22            2
# 23            pdxwebproperties.com           2       23            2
# 24                 www.youtube.com           2       24            2
# 25             www.stickermule.com           2       25            2
# 26                 plus.google.com           2       26            2
# 27                itunes.apple.com           2       27            2
# 28          training.talkpython.fm           2       28            2
# 29                          goo.gl           2       29            2
# 30                       gitter.im           2       30            2
# 31          training.talkpython.fm           2       31            2
# 32              www.pythongear.com           2       32            2
# 33          training.talkpython.fm           2       33            2
# 34                www.facebook.com           2       34            2
# 35        blog.michaelckennedy.net           2       35            2
# 36          training.talkpython.fm           2       36            2
# 37                   backtracks.fm           2       37            2
# 38                     twitter.com           2       38            2
# 39                 www.patreon.com           2       39            2
#
#                                                   url  lookup_id
# 0                        https://www.cas-donoghue.org          1
# 1                          https://donoghuc.github.io          1
# 2                               https://talkpython.fm          1
# 3           https://github.com/donoghuc/casadilla_web          1
# 4                         https://github.com/donoghuc          1
# 5                        https://twitter.com/mkennedy          1
# 6   https://stackoverflow.com/users/9034974/cas-do...          1
# 7               https://www.linkedin.com/in/casadilla          1
# 8                        https://www.podcastinit.com/          1
# 9                             https://pythonbytes.fm/          1
# 10                https://gimletmedia.com/science-vs/          1
# 11                             https://talkpython.fm/          1
# 12            https://www.dataengineeringpodcast.com/          1
# 13                             https://changelog.com/          1
# 14                            http://testandcode.com/          1
# 15             https://www.linkedin.com/in/casadilla/          1
# 16                           https://dataskeptic.com/          1
# 17                 https://rollbar.com/talkpythontome          1
# 18                  https://soundcloud.com/talkpython          1
# 19                          https://cash.me/$mkennedy          1
# 20                      https://gitter.im/talk-python          1
# 21                    https://facebook.com/talkpython          1
# 22                     https://twitter.com/TalkPython          1
# 23                       http://pdxwebproperties.com/          1
# 24  https://www.youtube.com/channel/UCKPSmMfDsXTKr...          1
# 25  https://www.stickermule.com/user/1070815159/st...          1
# 26  https://plus.google.com/u/0/b/1076024637045022...          1
# 27  https://itunes.apple.com/us/podcast/talk-pytho...          1
# 28  https://training.talkpython.fm/courses/explore...          1
# 29  https://goo.gl/app/playmusic?ibi=com.google.Pl...          1
# 30                https://gitter.im/talk-python/Lobby          1
# 31                    https://training.talkpython.fm/          1
# 32  http://www.pythongear.com/products/talk-python...          1
# 33  https://training.talkpython.fm/courses/explore...          1
# 34                https://www.facebook.com/talkpython          1
# 35                    http://blog.michaelckennedy.net          1
# 36  https://training.talkpython.fm/courses/explore...          1
# 37  https://backtracks.fm/talkpython/r/talkpython....          1
# 38   https://twitter.com/TalkPython/lists/show-guests          1
# 39                   https://www.patreon.com/mkennedy          1
