# %%
import sqlite3 as lite
import pandas as pd
import os

# %% [markdown]
# # path to db

# %%
db_path = os.path.join(os.getcwd(), 'crawler_app', 'crawler_app', 'db', 'crawler.sqlite')

# %% [markdown]
# # code to get all table names

# %%
def get_table_names(database):
    ''' print out all the table names in an SQLite db'''
    conn = lite.connect(database)
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    print(cursor.fetchall())
    conn.close()
get_table_names(db_path)
# Out:
# [('Account',), ('History',), ('Graph_Data',)]

# %%
def execute_statement(query, database):
    """ Execute a query and return results as dataframe. 
        ARGS: SQL statement, database path
        RETURN: dataframe with results
    """
    conn = lite.connect(database)
    result = pd.read_sql_query(query, conn)
    conn.close()
    return result

# %%
query = \
"""
SELECT * FROM Account
"""
execute_statement(query, db_path)
# Out:
#                                  id username  \
# 0  d73a3c1052bc4406a99ef6cf1526a1ce      cas
#
#                                        password_hash  \
# 0  $6$rounds=150000$2uqNZOg05eO063wt$FAARMIlW/kDB...
#
#                       created
# 0  2018-02-26 15:44:37.522890

# %%
query = \
"""
SELECT * FROM History
"""
execute_statement(query, db_path)
# Out:
#    auto_id                           user_id                      url  \
# 0        1  d73a3c1052bc4406a99ef6cf1526a1ce  https://www.caelum.site
# 1        2  d73a3c1052bc4406a99ef6cf1526a1ce  https://www.caelum.site
#
#   search_type                     created
# 0         BFS  2018-02-26 15:45:35.337803
# 1         BFS  2018-02-26 15:46:48.728056

# %%
query = \
"""
SELECT * FROM Graph_Data
"""
execute_statement(query, db_path)
# Out:
#                   domain  node_depth  node_id  parent_node  \
# 0        www.caelum.site           0        0            0
# 1             github.com           1        1            0
# 2   www.cas-donoghue.org           1        2            0
# 3             github.com           2        3            1
# 4             github.com           2        4            1
# 5      status.github.com           2        5            1
# 6        help.github.com           2        6            1
# 7             github.com           2        7            1
# 8    training.github.com           2        8            1
# 9             github.com           2        9            1
# 10            github.com           2       10            1
# 11       help.github.com           2       11            1
# 12  developer.github.com           2       12            1
# 13       shop.github.com           2       13            1
# 14       help.github.com           2       14            1
# 15       www.caelum.site           2       15            1
# 16       help.github.com           2       16            1
# 17            github.com           2       17            1
# 18         talkpython.fm           2       18            2
# 19           twitter.com           2       19            2
# 20      www.linkedin.com           2       20            2
# 21            github.com           2       21            2
# 22    donoghuc.github.io           2       22            2
# 23       www.caelum.site           0        0            0
# 24            github.com           1        1            0
# 25  www.cas-donoghue.org           1        2            0
# 26            github.com           2        3            1
# 27            github.com           2        4            1
# 28     status.github.com           2        5            1
# 29       help.github.com           2        6            1
# 30            github.com           2        7            1
# 31   training.github.com           2        8            1
# 32            github.com           2        9            1
# 33            github.com           2       10            1
# 34       help.github.com           2       11            1
# 35  developer.github.com           2       12            1
# 36       shop.github.com           2       13            1
# 37       help.github.com           2       14            1
# 38       www.caelum.site           2       15            1
# 39       help.github.com           2       16            1
# 40            github.com           2       17            1
# 41         talkpython.fm           2       18            2
# 42           twitter.com           2       19            2
# 43      www.linkedin.com           2       20            2
# 44            github.com           2       21            2
# 45    donoghuc.github.io           2       22            2
#
#                                                   url  lookup_id
# 0                             https://www.caelum.site          1
# 1      https://github.com/donoghuc/visual_web_crawler          1
# 2                       https://www.cas-donoghue.org/          1
# 3                                 https://github.com/          1
# 4                          https://github.com/contact          1
# 5                          https://status.github.com/          1
# 6   https://help.github.com/articles/which-remote-...          1
# 7                            https://github.com/about          1
# 8                         https://training.github.com          1
# 9                             https://github.com/blog          1
# 10                                 https://github.com          1
# 11  https://help.github.com/articles/github-security/          1
# 12                       https://developer.github.com          1
# 13                            https://shop.github.com          1
# 14  https://help.github.com/articles/github-terms-...          1
# 15                           https://www.caelum.site/          1
# 16                            https://help.github.com          1
# 17                    https://github.com/site/privacy          1
# 18                              https://talkpython.fm          1
# 19                       https://twitter.com/mkennedy          1
# 20              https://www.linkedin.com/in/casadilla          1
# 21          https://github.com/donoghuc/casadilla_web          1
# 22                         https://donoghuc.github.io          1
# 23                            https://www.caelum.site          2
# 24     https://github.com/donoghuc/visual_web_crawler          2
# 25                      https://www.cas-donoghue.org/          2
# 26                                https://github.com/          2
# 27                         https://github.com/contact          2
# 28                         https://status.github.com/          2
# 29  https://help.github.com/articles/which-remote-...          2
# 30                           https://github.com/about          2
# 31                        https://training.github.com          2
# 32                            https://github.com/blog          2
# 33                                 https://github.com          2
# 34  https://help.github.com/articles/github-security/          2
# 35                       https://developer.github.com          2
# 36                            https://shop.github.com          2
# 37  https://help.github.com/articles/github-terms-...          2
# 38                           https://www.caelum.site/          2
# 39                            https://help.github.com          2
# 40                    https://github.com/site/privacy          2
# 41                              https://talkpython.fm          2
# 42                       https://twitter.com/mkennedy          2
# 43              https://www.linkedin.com/in/casadilla          2
# 44          https://github.com/donoghuc/casadilla_web          2
# 45                         https://donoghuc.github.io          2
