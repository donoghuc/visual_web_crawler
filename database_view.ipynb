# %%
import sqlite3 as lite
import pandas as pd
import os

# %% [markdown]
# # path to db

# %%
db_path = os.path.join(os.getcwd(), 'crawler_app', 'crawler_app', 'db', 'crawler.sqlite')

# %% [markdown]
# # code to get all table names

# %%
def get_table_names(database):
    ''' print out all the table names in an SQLite db'''
    conn = lite.connect(database)
    cursor = conn.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    print(cursor.fetchall())
    conn.close()
get_table_names(db_path)
# Out:
# [('Account',), ('History',), ('Graph_Data',)]

# %%
def execute_statement(query, database):
    """ Execute a query and return results as dataframe. 
        ARGS: SQL statement, database path
        RETURN: dataframe with results
    """
    conn = lite.connect(database)
    result = pd.read_sql_query(query, conn)
    conn.close()
    return result

# %%
query = \
"""
SELECT * FROM Account
"""
execute_statement(query, db_path)
# Out:
#                                  id username  \
# 0  1d9b244296e64d64a0ac7958d75ac860      cas
#
#                                        password_hash  \
# 0  $6$rounds=150000$XEJvRXLPzFkeSomp$ak8Y8vngZ8pS...
#
#                       created
# 0  2018-02-26 16:16:23.148359

# %%
query = \
"""
SELECT * FROM History
"""
execute_statement(query, db_path)
# Out:
#    auto_id                           user_id                           url  \
# 0        1  1d9b244296e64d64a0ac7958d75ac860       https://www.caelum.site
# 1        2  1d9b244296e64d64a0ac7958d75ac860  https://www.cas-donoghue.org
#
#   search_type                     created
# 0         BFS  2018-02-26 16:19:36.177950
# 1         BFS  2018-02-26 16:22:26.524200

# %%
query = \
"""
SELECT * FROM Graph_Data
"""
execute_statement(query, db_path)
# Out:
#                              domain  node_depth  node_id  parent_node  \
# 0                   www.caelum.site           0        0            0
# 1              www.cas-donoghue.org           1        1            0
# 2                        github.com           1        2            0
# 3                        github.com           2        3            1
# 4                        github.com           2        4            1
# 5                       twitter.com           2        5            1
# 6                     talkpython.fm           2        6            1
# 7                  www.linkedin.com           2        7            1
# 8                donoghuc.github.io           2        8            1
# 9                        github.com           2        9            2
# 10                  help.github.com           2       10            2
# 11                       github.com           2       11            2
# 12                  help.github.com           2       12            2
# 13                  help.github.com           2       13            2
# 14                       github.com           2       14            2
# 15                status.github.com           2       15            2
# 16                       github.com           2       16            2
# 17                       github.com           2       17            2
# 18             developer.github.com           2       18            2
# 19                  shop.github.com           2       19            2
# 20              training.github.com           2       20            2
# 21                  help.github.com           2       21            2
# 22                  www.caelum.site           2       22            2
# 23             www.cas-donoghue.org           0        0            0
# 24                       github.com           1        1            0
# 25                       github.com           1        2            0
# 26                      twitter.com           1        3            0
# 27                    talkpython.fm           1        4            0
# 28                 www.linkedin.com           1        5            0
# 29               donoghuc.github.io           1        6            0
# ..                              ...         ...      ...          ...
# 78                             t.co           2       55            3
# 79                          cash.me           2       56            4
# 80                 www.facebook.com           2       57            4
# 81              www.stickermule.com           2       58            4
# 82           training.talkpython.fm           2       59            4
# 83             pdxwebproperties.com           2       60            4
# 84                      rollbar.com           2       61            4
# 85                      twitter.com           2       62            4
# 86                  www.patreon.com           2       63            4
# 87                   pythonbytes.fm           2       64            4
# 88                   soundcloud.com           2       65            4
# 89                     facebook.com           2       66            4
# 90           training.talkpython.fm           2       67            4
# 91                  plus.google.com           2       68            4
# 92                      twitter.com           2       69            4
# 93                      twitter.com           2       70            4
# 94                  www.youtube.com           2       71            4
# 95                        gitter.im           2       72            4
# 96           training.talkpython.fm           2       73            4
# 97                        gitter.im           2       74            4
# 98           training.talkpython.fm           2       75            4
# 99         blog.michaelckennedy.net           2       76            4
# 100                itunes.apple.com           2       77            4
# 101  www.dataengineeringpodcast.com           2       78            6
# 102                www.linkedin.com           2       79            6
# 103                 gimletmedia.com           2       80            6
# 104             www.podcastinit.com           2       81            6
# 105                   changelog.com           2       82            6
# 106                   talkpython.fm           2       83            6
# 107                 testandcode.com           2       84            6
#
#                                                    url  lookup_id
# 0                              https://www.caelum.site          1
# 1                        https://www.cas-donoghue.org/          1
# 2       https://github.com/donoghuc/visual_web_crawler          1
# 3            https://github.com/donoghuc/casadilla_web          1
# 4                          https://github.com/donoghuc          1
# 5                         https://twitter.com/mkennedy          1
# 6                                https://talkpython.fm          1
# 7                https://www.linkedin.com/in/casadilla          1
# 8                           https://donoghuc.github.io          1
# 9                      https://github.com/site/privacy          1
# 10                             https://help.github.com          1
# 11                          https://github.com/contact          1
# 12   https://help.github.com/articles/github-terms-...          1
# 13   https://help.github.com/articles/github-security/          1
# 14                            https://github.com/about          1
# 15                          https://status.github.com/          1
# 16                                 https://github.com/          1
# 17                             https://github.com/blog          1
# 18                        https://developer.github.com          1
# 19                             https://shop.github.com          1
# 20                         https://training.github.com          1
# 21   https://help.github.com/articles/which-remote-...          1
# 22                            https://www.caelum.site/          1
# 23                        https://www.cas-donoghue.org          2
# 24           https://github.com/donoghuc/casadilla_web          2
# 25                         https://github.com/donoghuc          2
# 26                        https://twitter.com/mkennedy          2
# 27                               https://talkpython.fm          2
# 28               https://www.linkedin.com/in/casadilla          2
# 29                          https://donoghuc.github.io          2
# ..                                                 ...        ...
# 78                             https://t.co/9WecoQ29g4          2
# 79                           https://cash.me/$mkennedy          2
# 80                 https://www.facebook.com/talkpython          2
# 81   https://www.stickermule.com/user/1070815159/st...          2
# 82   https://training.talkpython.fm/courses/explore...          2
# 83                        http://pdxwebproperties.com/          2
# 84                  https://rollbar.com/talkpythontome          2
# 85                      https://twitter.com/talkpython          2
# 86                    https://www.patreon.com/mkennedy          2
# 87                             https://pythonbytes.fm/          2
# 88                   https://soundcloud.com/talkpython          2
# 89                     https://facebook.com/talkpython          2
# 90                     https://training.talkpython.fm/          2
# 91   https://plus.google.com/u/0/b/1076024637045022...          2
# 92    https://twitter.com/TalkPython/lists/show-guests          2
# 93                      https://twitter.com/TalkPython          2
# 94   https://www.youtube.com/channel/UCKPSmMfDsXTKr...          2
# 95                 https://gitter.im/talk-python/Lobby          2
# 96   https://training.talkpython.fm/courses/explore...          2
# 97                       https://gitter.im/talk-python          2
# 98   https://training.talkpython.fm/courses/explore...          2
# 99                     http://blog.michaelckennedy.net          2
# 100  https://itunes.apple.com/us/podcast/talk-pytho...          2
# 101            https://www.dataengineeringpodcast.com/          2
# 102             https://www.linkedin.com/in/casadilla/          2
# 103                https://gimletmedia.com/science-vs/          2
# 104                       https://www.podcastinit.com/          2
# 105                             https://changelog.com/          2
# 106                             https://talkpython.fm/          2
# 107                            http://testandcode.com/          2
#
# [108 rows x 6 columns]
